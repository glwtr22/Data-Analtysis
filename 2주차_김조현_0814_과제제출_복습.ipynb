# %% [markdown]
# ### 데이터 전처리
#
# 데이터의 양적/질적 수준이 분석의 수준을 결정한다.
#
# 데이터 분석 업무의 80~90%는 데이터를 수집하고 정제하는 사전적인 전처리 업무이다.

# %% [markdown]
# - query() : 행 추출
# - df[] : 열 추출(변수, 열/칼럼)
# - sort_values() : 정렬
# - groupby() : 그룹화 연산, 그룹 객체 만들기
# - assign() : 변수 추가
# - agg() : 통계치 구하기
# - merge() : 열 기준 데이터 합치기
# - concat() : 행 기준 데이터 합치기

# %%
import pandas as pd

# %%
exam = pd.read_csv('resource/exam.csv')

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ###### query() 함수
#
# ** 판다스에서 조건에 부합하는 데이터를 추출할 때 가장 많이 사용
#
# 1) 비교 연산자 (==, >, >=, <, <=, !=)
#
# 2) in / not in 연산자 (in, not in)
#
# 3) 논리 연산자 (and, or, not)
#
# 4) 외부 변수 혹은 함수 참조 연산
#
# 5) 인덱스 검색
#
# 6) 문자열 부분 검색 (str.contains, str.startswith, str.endswith)

# %%
exam.query('nclass') # 전체 행이 출력된다 ... (근데 왜 행이 반복되서 나오는지...)
# Out:
#    id  nclass  math  english  science
# 1   2       1    60       97       60
# 1   2       1    60       97       60
# 1   2       1    60       97       60
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 2   3       1    45       86       78
# 2   3       1    45       86       78
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 3   4       1    30       98       58
# 3   4       1    30       98       58
# 3   4       1    30       98       58
# 4   5       2    25       80       65
# 4   5       2    25       80       65
# 4   5       2    25       80       65
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 5   6       2    50       89       98
# 5   6       2    50       89       98
# 5   6       2    50       89       98

# %%
exam.query('nclass==1') # nclass == 1 인 행 추출 / 비교 연산자 이용
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass != 1')
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('math >= 65')
# Out:
#     id  nclass  math  english  science
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('math<65 and english>80')  # 비교 연산자와 논리 연산자 이용
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65

# %%
exam.query('math<65 | english > 80 & science > 50')  # and or not 순서 : not -> and -> or
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65
# 19  20       5    78       83       58

# %%
exam.query('nclass in [5]')
# Out:
#     id  nclass  math  english  science
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# 내가 원하는 데이터를 query해 변수에 대입한 후, 데이터 프레임을 분석할 수 있다.

# %%
df_nc1 = exam.query('nclass == 5')

# %%
df_nc1
# Out:
#     id  nclass  math  english  science
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df_nc1['english'].mean()
# Out:
# 74.25

# %% [markdown]
# ### 변수 추출

# %%
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam[['id', 'math', 'english', 'science']]
# Out:
#     id  math  english  science
# 0    1    50       98       50
# 1    2    60       97       60
# 2    3    45       86       78
# 3    4    30       98       58
# 4    5    25       80       65
# 5    6    50       89       98
# 6    7    80       90       45
# 7    8    90       78       25
# 8    9    20       98       15
# 9   10    50       98       45
# 10  11    65       65       65
# 11  12    45       85       32
# 12  13    46       98       65
# 13  14    48       87       12
# 14  15    75       56       78
# 15  16    58       98       65
# 16  17    65       68       98
# 17  18    80       78       90
# 18  19    89       68       87
# 19  20    78       83       58

# %%
exam['math'].to_frame()
# Out:
#     math
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78

# %% [markdown]
# - 변수를 하나만 추출할 때는 단일 리스트로 추출
#
#     (but Series 형태로 추출되므로, 데이터 프레임으로 변환하고 싶으면 .to_frame() 함수 사용)
#
#
# - 변수를 두 개 이상 추출할 떄는 이중 리스트에 넣어서 추출

# %%
exam['new_df'] = 1

# %%
exam
# Out:
#     id  nclass  math  english  science  new_df
# 0    1       1    50       98       50       1
# 1    2       1    60       97       60       1
# 2    3       1    45       86       78       1
# 3    4       1    30       98       58       1
# 4    5       2    25       80       65       1
# 5    6       2    50       89       98       1
# 6    7       2    80       90       45       1
# 7    8       2    90       78       25       1
# 8    9       3    20       98       15       1
# 9   10       3    50       98       45       1
# 10  11       3    65       65       65       1
# 11  12       3    45       85       32       1
# 12  13       4    46       98       65       1
# 13  14       4    48       87       12       1
# 14  15       4    75       56       78       1
# 15  16       4    58       98       65       1
# 16  17       5    65       68       98       1
# 17  18       5    80       78       90       1
# 18  19       5    89       68       87       1
# 19  20       5    78       83       58       1

# %% [markdown]
# 변수를 제거하고 싶은 경우 : drop() 함수 사용
#
# inplace 변수를 True로 설정해야지 실제 데이터에 문법이 적용된다.

# %%
exam.drop(columns = 'new_df', inplace = True)

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ### query()와 []로 행 추출/ 열 추출을 조합하자!
#
# query()[] 와 같은 형태로 행과 열을 같이 추출할 수 있다.

# %%
exam.query('nclass==1')['english']
# Out:
# 0    98
# 1    97
# 2    86
# 3    98
# Name: english, dtype: int64

# %%
exam.query('math > 50')[['math', 'science']]
# Out:
#     math  science
# 1     60       60
# 6     80       45
# 7     90       25
# 10    65       65
# 14    75       78
# 15    58       65
# 16    65       98
# 17    80       90
# 18    89       87
# 19    78       58

# %%
exam.query('math>50')[['id', 'math', 'science']].head()
# Out:
#     id  math  science
# 1    2    60       60
# 6    7    80       45
# 7    8    90       25
# 10  11    65       65
# 14  15    75       78

# %% [markdown]
# ###### sort_values()
# ** 데이터 정렬
#
# - 디폴트 값이 "오름차순" 이다
# - 내림차순으로 보려면 ascending = False

# %%
exam.sort_values('math')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %%
exam.sort_values('math', ascending = False)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 0    1       1    50       98       50
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 11  12       3    45       85       32
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %% [markdown]
# ###### 여러 변수를 가지고 정렬
#
# - 리스트의 첫 번째 변수 기준으로 먼저 정렬 후, 그 이후 변수들 기준으로 정렬된다.
# - 차순의 종류를 각각 조정하고 싶으면, ascending 변수에 리스트로 True, False 넣어주기

# %%
exam.sort_values(['math', 'english'])
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 11  12       3    45       85       32
# 2    3       1    45       86       78
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 5    6       2    50       89       98
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %%
exam.sort_values(['math', 'english'], ascending = [True, False])
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %% [markdown]
# ###### assign()
# ** 기존에 존재하는 행들 이외로 새 행을 할당할 수 있다.
#
# - 기존에 존재하는 변수들을 이용해서 파생 변수를 새롭게 만들 수도 있다.
# - 새롭게 만든 파생 변수를 assign() 함수를 이용해서 새 행으로 할당할 수 있다.

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'], mean = (exam['math'] + exam['english'] + exam['science'])/3)
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# 15  16       4    58       98       65    221  73.666667
# 16  17       5    65       68       98    231  77.000000
# 17  18       5    80       78       90    248  82.666667
# 18  19       5    89       68       87    244  81.333333
# 19  20       5    78       83       58    219  73.000000

# %%
exam_total_mean = exam.assign(total = exam['math'] + exam['english'] + exam['science'], mean = (exam['math'] + exam['english'] + exam['science'])/3)

# %%
exam_total_mean
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# 15  16       4    58       98       65    221  73.666667
# 16  17       5    65       68       98    231  77.000000
# 17  18       5    80       78       90    248  82.666667
# 18  19       5    89       68       87    244  81.333333
# 19  20       5    78       83       58    219  73.000000

# %%
# 파생 변수 만들어서 바로 할당하는 방법

exam['total'] = exam['math'] + exam['english'] + exam['science']

# %%
exam
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# 15  16       4    58       98       65    221  73.666667
# 16  17       5    65       68       98    231  77.000000
# 17  18       5    80       78       90    248  82.666667
# 18  19       5    89       68       87    244  81.333333
# 19  20       5    78       83       58    219  73.000000

# %%
import numpy as np

# %%
# np.where을 이용해 새로운 열 할당하기

exam.assign(test = np.where(exam['math']>=80, 'pass', 'fail'))
# Out:
#     id  nclass  math  english  science  total       mean  test
# 0    1       1    50       98       50    198  66.000000  fail
# 1    2       1    60       97       60    217  72.333333  fail
# 2    3       1    45       86       78    209  69.666667  fail
# 3    4       1    30       98       58    186  62.000000  fail
# 4    5       2    25       80       65    170  56.666667  fail
# 5    6       2    50       89       98    237  79.000000  fail
# 6    7       2    80       90       45    215  71.666667  pass
# 7    8       2    90       78       25    193  64.333333  pass
# 8    9       3    20       98       15    133  44.333333  fail
# 9   10       3    50       98       45    193  64.333333  fail
# 10  11       3    65       65       65    195  65.000000  fail
# 11  12       3    45       85       32    162  54.000000  fail
# 12  13       4    46       98       65    209  69.666667  fail
# 13  14       4    48       87       12    147  49.000000  fail
# 14  15       4    75       56       78    209  69.666667  fail
# 15  16       4    58       98       65    221  73.666667  fail
# 16  17       5    65       68       98    231  77.000000  fail
# 17  18       5    80       78       90    248  82.666667  pass
# 18  19       5    89       68       87    244  81.333333  pass
# 19  20       5    78       83       58    219  73.000000  fail

# %%
# 새로운 변수 만들어서 할당하고 해당 변수를 기준으로 정렬하기

exam.assign(total_reverse = exam['math'] + exam['english'] + exam['science']).sort_values('total', ascending = False)
# Out:
#     id  nclass  math  english  science  total       mean  total_reverse
# 17  18       5    80       78       90    248  82.666667            248
# 18  19       5    89       68       87    244  81.333333            244
# 5    6       2    50       89       98    237  79.000000            237
# 16  17       5    65       68       98    231  77.000000            231
# 15  16       4    58       98       65    221  73.666667            221
# 19  20       5    78       83       58    219  73.000000            219
# 1    2       1    60       97       60    217  72.333333            217
# 6    7       2    80       90       45    215  71.666667            215
# 12  13       4    46       98       65    209  69.666667            209
# 2    3       1    45       86       78    209  69.666667            209
# 14  15       4    75       56       78    209  69.666667            209
# 0    1       1    50       98       50    198  66.000000            198
# 10  11       3    65       65       65    195  65.000000            195
# 9   10       3    50       98       45    193  64.333333            193
# 7    8       2    90       78       25    193  64.333333            193
# 3    4       1    30       98       58    186  62.000000            186
# 4    5       2    25       80       65    170  56.666667            170
# 11  12       3    45       85       32    162  54.000000            162
# 13  14       4    48       87       12    147  49.000000            147
# 8    9       3    20       98       15    133  44.333333            133

# %%
# lambda 식 사용한 전처리

exam.assign(new_total = lambda x : x['math'] + x['english'] + x['science'], new_mean = lambda x : x['new_total']/3)
# Out:
#     id  nclass  math  english  science  total       mean  new_total   new_mean
# 0    1       1    50       98       50    198  66.000000        198  66.000000
# 1    2       1    60       97       60    217  72.333333        217  72.333333
# 2    3       1    45       86       78    209  69.666667        209  69.666667
# 3    4       1    30       98       58    186  62.000000        186  62.000000
# 4    5       2    25       80       65    170  56.666667        170  56.666667
# 5    6       2    50       89       98    237  79.000000        237  79.000000
# 6    7       2    80       90       45    215  71.666667        215  71.666667
# 7    8       2    90       78       25    193  64.333333        193  64.333333
# 8    9       3    20       98       15    133  44.333333        133  44.333333
# 9   10       3    50       98       45    193  64.333333        193  64.333333
# 10  11       3    65       65       65    195  65.000000        195  65.000000
# 11  12       3    45       85       32    162  54.000000        162  54.000000
# 12  13       4    46       98       65    209  69.666667        209  69.666667
# 13  14       4    48       87       12    147  49.000000        147  49.000000
# 14  15       4    75       56       78    209  69.666667        209  69.666667
# 15  16       4    58       98       65    221  73.666667        221  73.666667
# 16  17       5    65       68       98    231  77.000000        231  77.000000
# 17  18       5    80       78       90    248  82.666667        248  82.666667
# 18  19       5    89       68       87    244  81.333333        244  81.333333
# 19  20       5    78       83       58    219  73.000000        219  73.000000

# %%
exam
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# 15  16       4    58       98       65    221  73.666667
# 16  17       5    65       68       98    231  77.000000
# 17  18       5    80       78       90    248  82.666667
# 18  19       5    89       68       87    244  81.333333
# 19  20       5    78       83       58    219  73.000000

# %% [markdown]
# ###### groupby()
# ** 데이터를 특정 기준으로 묶어서 통계 또는 집계 결과를 얻기 위해서 사용
#
# - agg와 함께 사용해서 통계치를 구하는 경우가 많다.
# - mean, max, sum, min, std, median과도 함께 사용할 수 있다.

# %%
exam.groupby('nclass').agg(mean_math = ('math', 'mean'))
# Out:
#         mean_math
# nclass
# 1           46.25
# 2           61.25
# 3           45.00
# 4           56.75
# 5           78.00

# %% [markdown]
# nclass를 기준으로 그룹을 나눈 후에, math 열을 선정해서 해당 열에 대한 mean 평균을 계산

# %%
exam.groupby('nclass').agg(mean_math = ('math', 'mean'), sum_math = ('math', 'sum'), median_math = ('math', 'median'), ct = ('math', 'count'))
# Out:
#         mean_math  sum_math  median_math  ct
# nclass
# 1           46.25       185         47.5   4
# 2           61.25       245         65.0   4
# 3           45.00       180         47.5   4
# 4           56.75       227         53.0   4
# 5           78.00       312         79.0   4
